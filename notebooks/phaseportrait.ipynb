# %%
# !pip install phaseportrait
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 743.2 kB/s eta 0:00:00
# ...

# %%
from phaseportrait import PhasePortrait2D
import numpy as np # We are also going to use it, for an example involving trigonometric functions

# %%
def dFRabbitsVsSheep(x, y):
    return x*(3-x-2*y), y*(2-x-y)

RabbitsVsSheep = PhasePortrait2D(dFRabbitsVsSheep, 3, MeshDim=25, Title='Rabbits vs Sheep', xlabel='Rabbits', ylabel='Sheep')
RabbitsVsSheep.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Rabbits vs Sheep'}, xlabel='Rabbits', ylabel='Sheep'>)

# %%
def dFPreyPredator(x, y):
    return x*(1.2-0.6*y), y*(0.3-0.8*x)

PreyPredator = PhasePortrait2D(dFPreyPredator, 3, MeshDim=25, Title='predator vs prey', xlabel='prey', ylabel='predator')
PreyPredator.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Rabbits vs Sheep'}, xlabel='Rabbits', ylabel='Sheep'>)

# %%
dfxy=input("Enter your differential equations:")

"""
def dFPreyPredator(x, y):
    return x*(1.2-0.6*y), y*(-0.3+0.8*x)
"""
def dFPreyPredator(x,y):
  return eval(dfxy)

PreyPredator = PhasePortrait2D(dFPreyPredator, 3, MeshDim=25, Title='predator vs prey', xlabel='prey', ylabel='predator')
PreyPredator.plot()
# Out:
# Enter your differential equations:x*(1.2-0.6*y), y*(-0.3+0.8*x)
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'predator vs prey'}, xlabel='prey', ylabel='predator'>)

# %%
def dFPreyPredator(x, y):
    return x*(1.2-0.6*y), y*(-0.8+0.3*x)

PreyPredator = PhasePortrait2D(dFPreyPredator, 3, MeshDim=25, Title='predator vs prey', xlabel='prey', ylabel='predator')
PreyPredator.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'predator vs prey'}, xlabel='prey', ylabel='predator'>)
